# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# !ls /gdrive
# Out:
# 'My Drive'

# %%
# !ls "/gdrive/My Drive"
# Out:
# 'Colab Notebooks'   KIDA_Project

# %%
# !ls "/gdrive/My Drive/KIDA_Project"
# Out:
# id_rsa	KIDA.ipynb  weight

# %%
! ls "/gdrive/My Drive/KIDA_Project/weight/age_net.caffemodel"
# Out:
# '/gdrive/My Drive/KIDA_Project/weight/age_net.caffemodel'

# %%
# %cd /gdrive/My Drive/KIDA_Project/weight
# Out:
# /gdrive/My Drive/KIDA_Project/weight

# %%
# !git clone https://github.com/jaewookJ/learnopencv.git
# Out:
# fatal: destination path 'learnopencv' already exists and is not an empty directory.

# %%
# %ls "/gdrive/My Drive/weight/learnopencv/AgeGender"
# Out:
# age_deploy.prototxt  gender_deploy.prototxt      opencv_face_detector_uint8.pb
# AgeGender.cpp        gender_net.caffemodel       README.md
# AgeGender.py         images/                     sample1.jpg
# age_net.caffemodel   learnopencv/                sample-output.jpg
# CMakeLists.txt       opencv_face_detector.pbtxt

# %%
# %cd "/gdrive/My Drive/weight/learnopencv/AgeGender"
# !cp ../../age_net.caffemodel ./
# !cp ../../gender_net.caffemodel ./
# !python  AgeGender.py
# Out:
# /gdrive/My Drive/weight/learnopencv/AgeGender
# [ WARN:0] global /io/opencv/modules/videoio/src/cap_v4l.cpp (802) open VIDEOIO ERROR: V4L: can't open camera by index 0

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
img = cv2.imread('sample-output.jpg', cv2.IMREAD_UNCHANGED)
from matplotlib.pyplot import imshow,axis
img2=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(img2)

# %%
ls
# Out:
# age_deploy.prototxt  gender_deploy.prototxt         README.md
# AgeGender.cpp        gender_net.caffemodel          sample1.jpg
# AgeGender.py         images/                        sample-output.jpg
# age_net.caffemodel   opencv_face_detector.pbtxt
# CMakeLists.txt       opencv_face_detector_uint8.pb

# %%
python AgeGender.py
# Out:
#   File "<ipython-input-21-bdc5dd0ef341>", line 1
#     python AgeGender.py
#                    ^
# SyntaxError: invalid syntax

# %%
ls
# Out:
# age_deploy.prototxt  gender_deploy.prototxt      opencv_face_detector_uint8.pb
# AgeGender.cpp        gender_net.caffemodel       README.md
# AgeGender.py         images/                     sample1.jpg
# age_net.caffemodel   learnopencv/                sample-output.jpg
# CMakeLists.txt       opencv_face_detector.pbtxt

# %%
cd images/
# Out:
# /gdrive/My Drive/weight/learnopencv/AgeGender/images

# %%
# !wget https://raw.githubusercontent.com/jaewookJ/KidaSetting/master/files/url_ec2.txt -O ~/url

# !echo "ec2-15-164-48-24.ap-northeast-2.compute.amazonaws.com" >~/url
# !echo $(cat ~/url)
# Out:
# --2020-03-31 03:11:56--  https://raw.githubusercontent.com/jaewookJ/KidaSetting/master/files/url_ec2.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘/root/url’
#
# /root/url           100%[===================>]      54  --.-KB/s    in 0s
#
# 2020-03-31 03:11:56 (16.8 MB/s) - ‘/root/url’ saved [54/54]
#
# ec2-15-164-48-24.ap-northeast-2.compute.amazonaws.com

# %%
# !echo "x1818" >> xx.html
# !ls "/gdrive/My Drive/KIDA_Project/id_rsa"
# !cp "/gdrive/My Drive/KIDA_Project/id_rsa" ./
# !pwd
# Out:
# '/gdrive/My Drive/KIDA_Project/id_rsa'
# /gdrive/My Drive/KIDA_Project/weight

# %%
# !chmod 600 id_rsa
# !scp -i id_rsa   -o "StrictHostKeyChecking no" xx.html ubuntu@$(cat ~/url):/var/www/html/weight/
# !ssh -i id_rsa   -o  "StrictHostKeyChecking no"  ubuntu@ec2-15-164-48-24.ap-northeast-2.compute.amazonaws.com chmod +r /var/www/html/weight/xx.html

# %%
# !ls -als
# Out:
# total 89177
# 44592 -rw-------  1 root root 45661480 Mar 18 05:46 age_net.caffemodel
# 44580 -rw-------  1 root root 45649168 Mar 18 06:36 gender_net.caffemodel
#     2 -rw-------  1 root root     1679 Mar 31 02:30 id_rsa
#     4 drwx------ 93 root root     4096 Mar 18 06:02 learnopencv
#     0 -rw-------  1 root root        0 Mar 31 02:26 test
#     0 -rw-------  1 root root        0 Mar 31 02:30 xx
